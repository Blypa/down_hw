# %%
import pandas as pd
import plotly.graph_objs as go

from collections import Counter
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from plotly.offline import init_notebook_mode, iplot

import nltk
nltk.download('punct')
nltk.download('stopwords')

init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Read data

# %%
df_train = pd.read_csv("./data/train.csv", names=["topic", "title", "article"])
df_test = pd.read_csv("./data/test.csv", names=["topic", "title", "article"])

# %%
df_train.sample(2)
# Out:
#        topic                                              title  \
# 92602      4  Dell and Microsoft collaborate to reduce patch...
# 36390      1  Powell, Libya Foreign Minister to Hold First T...
#
#                                                  article
# 92602  Dell and Microsoft are to combine their patch ...
# 36390   UNITED NATIONS (Reuters) - In a sign of warmi...

# %%
df_test.sample(2)
# Out:
#       topic                                              title  \
# 3282      4  Qatar Defense Show Focuses on Videogame Techno...
# 5230      1  Militants holding UN workers say talks have be...
#
#                                                 article
# 3282   DOHA (Reuters) - Rick Bracewell is driving th...
# 5230  Militants threatening to kill three UN hostage...

# %% [markdown]
# ## EDA

# %% [markdown]
# #### Check class balance

# %%
df_train["topic"].value_counts()
# Out:
# 3    30000
# 4    30000
# 2    30000
# 1    30000
# Name: topic, dtype: int64

# %%
df_test["topic"].value_counts()
# Out:
# 3    1900
# 4    1900
# 2    1900
# 1    1900
# Name: topic, dtype: int64

# %% [markdown]
# #### Check if sets have missing values

# %%
print(f"""
\ttrain:
{df_train.isna().any()}
\ttest:
{df_test.isna().any()}
""")
# Out:
# 	train:
# topic      False
# title      False
# article    False
# dtype: bool
# 	test:
# topic      False
# title      False
# article    False
# dtype: bool

# %% [markdown]
# #### Compare word count distribution over sets

# %%
df_train['title_word_count'] = df_train['title'].apply(lambda x : len(x.split())) # word_tokenize(x) runs long for EDA
df_train['article_word_count'] = df_train['article'].apply(lambda x : len(x.split()))

df_test['title_word_count'] = df_test['title'].apply(lambda x : len(x.split()))
df_test['article_word_count'] = df_test['article'].apply(lambda x : len(x.split()))

# %%
trace1 = go.Histogram(x=df_train['title_word_count'], opacity=0.5, histnorm="percent",
                      name="Train title word count")
trace2 = go.Histogram(x=df_test['title_word_count'], opacity=0.5, histnorm="percent",
                      name="Test title word count")


data = [trace1, trace2]
layout = go.Layout(barmode='overlay',
                   title='Word count of titles',
                   xaxis=dict(title='Word count'),
                   yaxis=dict(title='Numer of titles'))

fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div>                            <div id="10679a30-8a58-4eb2-9e09-25210e0974c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("10679a30-8a58-4eb2-9e09-25210e0974c2")) {                    Plotly.newPlot(                        "10679a30-8a58-4eb2-9e09-25210e0974c2",                        [{"histnorm":"percent","name":"Train title word count","opacity":0.5,"x":[9,6,7,9,13,8,7,7,3,8,6,8,5,7,7,4,4,8,6,6,5,4,4,7,6,5,5,6,5,6,5,5,7,6,5,4,6,4,7,7,1,5,5,6,9,8,8,7,6,4,4,2,3,12,4,4,3,4,6,9,5,19,9,14,4,9,3,7,8,4,10,7,5,6,4,5,5,5,8,8,10,7,10,6,6,9,7,8,10,7,7,6,8,7,9,9,6,11,8,8,9,6,10,9,8,7,8,9,8,10,7,9,7,6,8,6,6,7,7,7,9,8,10,7,7,6,15,8,9,7,9,6,8,6,7,8,7,6,8,7,7,7,7,9,8,7,7,7,8,6,8,8,6,7,6,8,7,6,6,7,8,8,3,6,4,8,5,5,3,4,6,3,2,5,3,7,4,2,4,2,3,5,3,4,4,8,7,4,6,8,6,4,4,5,6,4,4,4,4,5,5,5,4,7,9,7,6,9,6,8
,6,7,6,8,7,7,8,7,5,7,8,7,6,6,3,8,8,7,7,5,9,4,6,6,8,7,10,8,8,5,8,8,8,6,7,7,6,5,5,7,5,8,5,6,7,6,9,11,13,4,7,6,5,7,6,6,9,8,12,9,4,5,7,7,7,8,13,7,8,6,10,5,5,6,7,7,9,4,8,9,6,5,8,13,7,12,11,11,7,6,10,5,4,7,13,6,6,8,4,9,7,5,5,8,6,8,7,9,5,5,5,3,8,8,9,5,9,8,7,6,8,8,5,6,6,7,7,8,5,6,7,7,6,8,9,7,7,7,8,8,7,8,7,12,6,9,9,8,7,4,10,4,8,5,8,10,4,8,11,8,6,7,7,7,8,10,7,6,10,4,7,5,12,5,7,6,3,4,3,3,3,8,8,7,8,9,7,6,6,7,8,4,6,5,8,5,7,5,8,8,8,7,5,9,11,8,7,7,12,11,7,5,7,12,8,3,9,7,7,5,7,14,8,6,7,7,7,6,5,5,3,8,5,5,7,6,8,4,8,3,5,6,3,10,5,6,4,9,7,8,8,5,7,7,5,4,3,5,8,6,7,6,6,2,7,4,7,6,8,7,7,4,8,9,3,7,7,8,9,8,7,7,8,8,6,5,7,7,7,7,7,5,5,8,8,8,7,4,8,7,10,5,2,7,7,9,6,7,6,5,8,4,9,2,3,6,7,6,7,5,6,5,6,6,6,9,5,7,5,7,7,3,8,9,5,11,8,8,4,4,5,6,7,6,8,6,7,7,6,6,6,6,7,6,4,7,7,5,6,11,5,7,7,6,5,8,4,14,7,6,6,8,5,9,6,8,9,9,7,7,8,7,8,6,5,7,12,6,7,7,6,7,4,12,7,9,8,9,7,5,8,5,6,8,8,8,8,7,7,4,7,6,10,5,6,8,6,6,7,8,6,6,6,5,8,8,5,4,5,7,5,7,5,7,8,9,7,3,4,5,5,8,9,5,7,7,9,10,6,12,6,5,10,5,4,6,10,5,7,5,11,6,8,7,6,10,6,6,5,5,5,2,8,5,5,8,5,8,11,6,10,6,7,4,7,11,5,7,4,5,7,11,2,5,5,5,8,2,4,3,8,10,8,6,7,9,7,7,8,11,8,10,9,6,7,5,4,3,8,10,7,9,8,6,5,4,4,4,6,7,6,7,9,7,7,6,4,7,6,8,11,6,7,7,7,7,11,5,8,9,5,4,9,5,4,5,6,5,6,8,11,9,6,5,5,7,6,5,6,6,7,5,5,8,4,7,7,8,8,7,7,6,7,6,7,6,5, ...

# %%
trace3 = go.Histogram(x=df_train['article_word_count'], opacity=0.5, histnorm="percent", 
                      name="Train arcticle word count")
trace4 = go.Histogram(x=df_test['article_word_count'], opacity=0.5, histnorm="percent", 
                      name="Test arcticle word count")


data = [trace3, trace4]
layout = go.Layout(barmode='overlay',
                   title='Word count of arcticles',
                   xaxis=dict(title='Word count'),
                   yaxis=dict(title='Numer of titles'))

fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div>                            <div id="62d1a0cf-4708-49f2-b33c-484c79f9e804" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("62d1a0cf-4708-49f2-b33c-484c79f9e804")) {                    Plotly.newPlot(                        "62d1a0cf-4708-49f2-b33c-484c79f9e804",                        [{"histnorm":"percent","name":"Train arcticle word count","opacity":0.5,"x":[12,30,29,27,24,30,28,32,65,15,34,37,22,34,39,24,21,39,22,20,20,22,17,23,22,23,23,20,22,22,20,22,25,23,20,25,33,38,51,60,63,38,26,43,43,25,21,27,29,13,15,19,24,21,18,12,17,17,42,73,37,54,37,36,54,56,59,48,26,53,39,40,34,32,29,37,27,36,
36,30,36,35,23,13,16,16,32,32,26,19,25,31,26,31,31,32,14,14,36,29,25,33,31,21,24,31,30,26,32,37,14,17,27,8,16,37,45,76,43,37,37,20,27,33,39,17,50,32,15,37,14,38,43,15,18,15,17,17,47,37,45,15,32,17,11,20,38,42,11,42,40,74,27,29,70,15,18,14,26,37,35,54,44,25,26,38,33,32,22,49,32,39,42,40,40,21,43,57,76,27,24,51,33,17,38,31,38,33,39,17,13,12,16,29,35,27,34,24,35,20,21,28,45,26,35,30,40,28,28,35,61,49,34,46,30,31,43,36,18,35,40,24,30,29,131,41,46,51,34,15,68,23,35,40,37,38,20,68,31,16,48,51,12,37,6,19,25,28,15,15,19,20,42,24,38,57,34,32,88,13,34,16,28,35,37,28,37,34,14,19,43,51,46,38,33,32,32,122,41,39,30,25,23,22,42,20,13,14,16,62,31,25, ...

# %% [markdown]
# #### Compare most common words in arcticles for each topic

# %%
def get_top_words(df, topic, n):
    sw = stopwords.words('english')
    sw.extend(['!', '"', '#', '$', '%', '&', "'", '(', ')', '*', '+', 
               ',', '-', '.', '/', ':', ';', '<', '=', '>', '?', '@', 
               '[', '\\', ']', '^', '_', '`', '{', '|', '}', '~', '#39;s'])
    
    text = df[df['topic'] == topic]["article"]
    
    words = " ".join(text).split()
    words = [x.lower() for x in words if x.lower() not in sw]
    
    ctnr = Counter(words)
    return ctnr.most_common(n)

# %%
print(get_top_words(df_train, 1, 10))
print(get_top_words(df_test, 1, 10))
# Out:
# [('said', 5408), ('president', 3652), ('two', 2895), ('minister', 2867), ('ap', 2768), ('new', 2603), ('(reuters)', 2478), ('iraq', 2466), ('us', 2414), ('killed', 2268)]
# [('said', 322), ('president', 234), ('ap', 193), ('two', 171), ('us', 162), ('(reuters)', 160), ('minister', 160), ('new', 160), ('iraq', 154), ('said.', 141)]

# %%
print(get_top_words(df_train, 2, 10))
print(get_top_words(df_test, 2, 10))
# Out:
# [('new', 3533), ('first', 3441), ('ap', 3100), ('last', 2622), ('--', 2513), ('world', 2460), ('two', 2409), ('team', 2328), ('one', 2314), ('game', 2303)]
# [('first', 231), ('new', 207), ('ap', 195), ('last', 174), ('two', 173), ('one', 169), ('win', 163), ('world', 162), ('--', 162), ('team', 150)]

# %%
print(get_top_words(df_train, 3, 10))
print(get_top_words(df_test, 3, 10))
# Out:
# [('said', 6607), ('new', 5714), ('(reuters)', 4296), ('oil', 3953), ('us', 3809), ('inc.', 3515), ('company', 3133), ('york', 2986), ('prices', 2782), ('u.s.', 2608)]
# [('said', 425), ('new', 352), ('(reuters)', 260), ('us', 254), ('inc.', 240), ('oil', 220), ('company', 191), ('york', 185), ('prices', 164), ('u.s.', 161)]

# %%
print(get_top_words(df_train, 4, 10))
print(get_top_words(df_test, 4, 10))
# Out:
# [('new', 5222), ('said', 3199), ('microsoft', 2766), ('software', 2646), ('internet', 2324), ('company', 2210), ('--', 1839), ('computer', 1786), ('inc.', 1777), ('first', 1765)]
# [('new', 327), ('said', 216), ('microsoft', 192), ('internet', 151), ('software', 149), ('company', 146), ('--', 144), ('inc.', 124), ('first', 120), ('computer', 108)]

# %%
words = " ".join(text).split()
words = [x.lower() for x in words if x.lower() not in sw]

# %%
ctnr = Counter(words)
ctnr.most_common(10)
# Out:
# [('said', 5408),
#  ('#39;s', 5190),
#  ('president', 3652),
#  ('two', 2895),
#  ('minister', 2867),
#  ('ap', 2768),
#  ('new', 2603),
#  ('(reuters)', 2478),
#  ('iraq', 2466),
#  ('us', 2414)]
